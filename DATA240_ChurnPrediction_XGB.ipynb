# %% [markdown]
# **Importing the Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import statsmodels.api as sm
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
import scikitplot as skplt

# %% [markdown]
# **Loading the dataset**

# %%
churn_data = pd.read_csv('https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/WA_Fn-UseC_-Telco-Customer-Churn.csv')
churn_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# **Data Preprocessing**

# %%
churn_data_1 = churn_data.copy()
churn_data_1.TotalCharges = pd.to_numeric(churn_data_1.TotalCharges, errors = 'coerce')
churn_data_1.dropna(how = 'any', inplace=True)
churn_data_1.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
churn_data_1.drop(columns = ['customerID'], axis=1, inplace=True)
churn_data_1.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
churn_data_1['PaymentMethod'] = churn_data_1['PaymentMethod'].str.replace('(automatic)','', regex=False)
churn_data_1.PaymentMethod.unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer ',
#        'Credit card '], dtype=object)

# %%
churn_data_1['Churn'] = np.where(churn_data_1.Churn == 'Yes', 1,0)
churn_data_1.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 0              Yes  Electronic check           29.85         29.85      0
# 1               No      Mailed check           56.95       1889.50      0
# 2              Yes      Mailed check           53.85        108.15      1
# 3               No    Bank transfer            42.30       1840.75      0
# 4              Yes  Electronic check           70.70        151.65      1

# %%
churn_data_1 = pd.get_dummies(churn_data_1)
churn_data_1.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0       1           29.85         29.85      0              1
# 1              0      34           56.95       1889.50      0              0
# 2              0       2           53.85        108.15      1              0
# 3              0      45           42.30       1840.75      0              0
# 4              0       2           70.70        151.65      1              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0            0           0            1              1  ...
# 1            1           1            0              1  ...
# 2            1           1            0              1  ...
# 3            1           1            0              1  ...
# 4            0           1            0              1  ...
#
#    StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                    0                        1                  0
# 1                    0                        0                  1
# 2                    0                        1                  0
# 3                    0                        0                  1
# 4                    0                        1                  0
#
#    Contract_Two year  PaperlessBilling_No  PaperlessBilling_Yes  \
# 0                  0                    0                     1
# 1                  0                    1                     0
# 2                  0                    0                     1
# 3                  0                    1                     0
# 4                  0                    0                     1
#
#    PaymentMethod_Bank transfer   PaymentMethod_Credit card   \
# 0                             0                           0
# 1                             0                           0
# 2                             0                           0
# 3                             1                           0
# 4                             0                           0
#
#    PaymentMethod_Electronic check  PaymentMethod_Mailed check
# 0                               1                           0
# 1                               0                           1
# 2                               0                           1
# 3                               0                           0
# 4                               1                           0
#
# [5 rows x 46 columns]

# %%
mms = StandardScaler()
churn_data_1[['MonthlyCharges', 'TotalCharges']] = mms.fit_transform(churn_data_1[['MonthlyCharges', 'TotalCharges']])
churn_data_1.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0       1       -1.161694     -0.994194      0              1
# 1              0      34       -0.260878     -0.173740      0              0
# 2              0       2       -0.363923     -0.959649      1              0
# 3              0      45       -0.747850     -0.195248      0              0
# 4              0       2        0.196178     -0.940457      1              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0            0           0            1              1  ...
# 1            1           1            0              1  ...
# 2            1           1            0              1  ...
# 3            1           1            0              1  ...
# 4            0           1            0              1  ...
#
#    StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                    0                        1                  0
# 1                    0                        0                  1
# 2                    0                        1                  0
# 3                    0                        0                  1
# 4                    0                        1                  0
#
#    Contract_Two year  PaperlessBilling_No  PaperlessBilling_Yes  \
# 0                  0                    0                     1
# 1                  0                    1                     0
# 2                  0                    0                     1
# 3                  0                    1                     0
# 4                  0                    0                     1
#
#    PaymentMethod_Bank transfer   PaymentMethod_Credit card   \
# 0                             0                           0
# 1                             0                           0
# 2                             0                           0
# 3                             1                           0
# 4                             0                           0
#
#    PaymentMethod_Electronic check  PaymentMethod_Mailed check
# 0                               1                           0
# 1                               0                           1
# 2                               0                           1
# 3                               0                           0
# 4                               1                           0
#
# [5 rows x 46 columns]

# %%
X1 = churn_data_1.drop(['Churn'], axis=1)
y1 = churn_data_1['Churn']
X1
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Female  \
# 0                 0       1       -1.161694     -0.994194              1
# 1                 0      34       -0.260878     -0.173740              0
# 2                 0       2       -0.363923     -0.959649              0
# 3                 0      45       -0.747850     -0.195248              0
# 4                 0       2        0.196178     -0.940457              1
# ...             ...     ...             ...           ...            ...
# 7038              0      24        0.664868     -0.129180              0
# 7039              0      72        1.276493      2.241056              1
# 7040              0      11       -1.170004     -0.854514              1
# 7041              1       4        0.319168     -0.872095              0
# 7042              0      66        1.357932      2.012344              0
#
#       gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# 0               0           0            1              1               0
# 1               1           1            0              1               0
# 2               1           1            0              1               0
# 3               1           1            0              1               0
# 4               0           1            0              1               0
# ...           ...         ...          ...            ...             ...
# 7038            1           0            1              0               1
# 7039            0           0            1              0               1
# 7040            0           0            1              0               1
# 7041            1           0            1              1               0
# 7042            1           1            0              1               0
#
#       ...  StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0     ...                    0                        1                  0
# 1     ...                    0                        0                  1
# 2     ...                    0                        1                  0
# 3     ...                    0                        0                  1
# 4     ...                    0                        1                  0
# ...   ...                  ...                      ...                ...
# 7038  ...                    1                        0                  1
# 7039  ...                    1                        0                  1
# 7040  ...                    0                        1                  0
# 7041  ...                    0                        1                  0
# 7042  ...                    1                        0                  0
#
#       Contract_Two year  PaperlessBilling_No  PaperlessBilling_Yes  \
# 0                     0                    0                     1
# 1                     0                    1                     0
# 2                     0                    0                     1
# 3                     0                    1                     0
# 4                     0                    0                     1
# ...                 ...                  ...                   ...
# 7038                  0                    0                     1
# 7039                  0                    0                     1
# 7040                  0                    0                     1
# 7041                  0                    0                     1
# 7042                  1                    0                     1
#
#       PaymentMethod_Bank transfer   PaymentMethod_Credit card   \
# 0                                0                           0
# 1                                0                           0
# 2                                0                           0
# 3                                1                           0
# 4                                0                           0
# ...                            ...                         ...
# 7038                             0                           0
# 7039                             0                           1
# 7040                             0                           0
# 7041                             0                           0
# 7042                             1                           0
#
#       PaymentMethod_Electronic check  PaymentMethod_Mailed check
# 0                                  1                           0
# 1                                  0                           1
# 2                                  0                           1
# 3                                  0                           0
# 4                                  1                           0
# ...                              ...                         ...
# 7038                               0                           1
# 7039                               0                           0
# 7040                               1                           0
# 7041                               0                           1
# 7042                               0                           0
#
# [7032 rows x 45 columns]

# %% [markdown]
# **Baseline Model**

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=1, stratify=y1)

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="reg:linear", random_state=42)
xgb_model.fit(X_train, y_train)
# Out:
# [18:00:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBClassifier(objective='reg:linear', random_state=42)

# %%
predictions_nb = xgb_model.predict(X_test)

# %%
print('\033[1m' + "Model Accuracy" + '\033[0m')
print("Accuracy of the model is:", accuracy_score(y_test, predictions_nb))
print("\n")
print('\033[1m' + "Confusion Matrix" + '\033[0m')
con_mat = pd.DataFrame(confusion_matrix(y_test, predictions_nb), index=['True[0]','True[1]'], 
                       columns=['Predict[0]', 'Predict[1]'])
print(con_mat)
print("\n")
print('\033[1m' + "Classification Report" + '\033[0m')
print(classification_report(y_test, predictions_nb))
# Out:
# Model Accuracy
# Accuracy of the model is: 0.7931769722814499
#
#
# Confusion Matrix
#          Predict[0]  Predict[1]
# True[0]         941          92
# True[1]         199         175
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87      1033
#            1       0.66      0.47      0.55       374
#
#     accuracy                           0.79      1407
#    macro avg       0.74      0.69      0.71      1407
# weighted avg       0.78      0.79      0.78      1407

# %%
skplt.metrics.plot_roc(y_test, xgb_model.predict_proba(X_test), plot_micro=False)
plt.show()

# %% [markdown]
# **SMOTE Technique**

# %%
print('\033[1m' + "Distribution of Target Variable Churn before Upsampling" + '\033[0m')
print(churn_data_1['Churn'].value_counts())
print("\n")
# Out:
# Distribution of Target Variable Churn before Upsampling
# 0    5163
# 1    1869
# Name: Churn, dtype: int64

# %%
X_os = churn_data_1.loc[:, churn_data_1.columns != 'Churn']
y_os = churn_data_1.loc[:, churn_data_1.columns == 'Churn']

# %%
from imblearn.over_sampling import SMOTE

os = SMOTE(random_state=0)
Xos_train, Xos_test, yos_train, yos_test = train_test_split(X_os, y_os, test_size=0.3, random_state=0)
columns = Xos_train.columns

# %%
os_data_X,os_data_y=os.fit_resample(Xos_train, yos_train)
os_data_X = pd.DataFrame(data=os_data_X,columns=columns )
os_data_y= pd.DataFrame(data=os_data_y,columns=['Churn'])

# %%
# Checking the numbers of our data
print("Length of oversampled data is ",len(os_data_X))
print("Number of NO churn in oversampled data:",len(os_data_y[os_data_y['Churn']==0]))
print("Number of churn:",len(os_data_y[os_data_y['Churn']==1]))
print("Proportion of NO churn data in oversampled data is ",len(os_data_y[os_data_y['Churn']==0])/len(os_data_X))
print("Proportion of churn data in oversampled data is ",len(os_data_y[os_data_y['Churn']==1])/len(os_data_X))
# Out:
# Length of oversampled data is  7216
# Number of NO churn in oversampled data: 3608
# Number of churn: 3608
# Proportion of NO churn data in oversampled data is  0.5
# Proportion of churn data in oversampled data is  0.5

# %% [markdown]
# **Feature Selection**

# %%
df_final_vars=churn_data_1.columns.values.tolist()
y=['Churn']
X=[i for i in df_final_vars if i not in y]

# %%
from sklearn.feature_selection import RFE

xgb_clf = xgb.XGBClassifier();
rfe = RFE(xgb_clf, step=20)
rfe = rfe.fit(os_data_X, os_data_y.values.ravel())
print(rfe.support_)
# Out:
# [False  True  True False False  True False False  True  True False False
#   True False False False  True  True  True False  True  True False False
#  False False False  True False  True False False False False False  True
#   True  True  True  True  True  True  True False  True]

# %%
ranking = rfe.support_
df_r = pd.DataFrame(ranking)
df_x = churn_data_1.copy()
df_x.drop(['Churn'], axis=1, inplace=True)
columns_x = df_x.columns.values
df_col = pd.DataFrame(columns_x)
df_ranking = df_col.merge(df_r, left_index=True, right_index=True, how='inner')
df_features = df_ranking.loc[df_ranking['0_y'] == True]
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 1 to 44
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0_x     22 non-null     object
#  1   0_y     22 non-null     bool
# dtypes: bool(1), object(1)
# memory usage: 374.0+ bytes

# %%
first_column = df_features.iloc[:, 0]
cols=first_column.to_list()
cols
# Out:
# ['tenure',
#  'MonthlyCharges',
#  'gender_Male',
#  'Dependents_No',
#  'Dependents_Yes',
#  'MultipleLines_No',
#  'InternetService_Fiber optic',
#  'InternetService_No',
#  'OnlineSecurity_No',
#  'OnlineSecurity_Yes',
#  'OnlineBackup_No',
#  'TechSupport_No',
#  'TechSupport_Yes',
#  'StreamingMovies_Yes',
#  'Contract_Month-to-month',
#  'Contract_One year',
#  'Contract_Two year',
#  'PaperlessBilling_No',
#  'PaperlessBilling_Yes',
#  'PaymentMethod_Bank transfer ',
#  'PaymentMethod_Credit card ',
#  'PaymentMethod_Mailed check']

# %% [markdown]
# **Updated XGB Model**

# %%
X=os_data_X[cols]
y=os_data_y["Churn"]

# %%
logit_model=sm.Logit(y,X)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.445080
#          Iterations 7
#                                Results: Logit
# =============================================================================
# Model:                   Logit                Pseudo R-squared:     0.358
# Dependent Variable:      Churn                AIC:                  6467.3933
# Date:                    2022-04-30 18:02     BIC:                  6618.8425
# No. Observations:        7216                 Log-Likelihood:       -3211.7
# Df Model:                21                   LL-Null:              -5001.8
# Df Residuals:            7194                 LLR p-value:          0.0000
# Converged:               1.0000               Scale:                1.0000
# No. Iterations:          7.0000
# -----------------------------------------------------------------------------
#                               Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------
# tenure                       -0.0143   0.0021  -6.8925 0.0000 -0.0184 -0.0103
# MonthlyCharges                0.3045   0.1139   2.6724 0.0075  0.0812  0.5278
# gender_Male                  -0.0420   0.0624  -0.6733 0.5007 -0.1643  0.0803
# Dependents_No                -0.0474   0.1398  -0.3392 0.7345 -0.3214  0.2266
# Dependents_Yes               -0.6139   0.1550  -3.9620 0.0001 -0.9176 -0.3102
# MultipleLines_No             -0.1987   0.0722  -2.7510 0.0059 -0.3402 -0.0571
# InternetService_Fiber optic   0.5819   0.1466   3.9697 0.0001  0.2946  0.8692
# InternetService_No           -0.0394   0.2487  -0.1583 0.8742 -0.5269  0.4481
# OnlineSecurity_No            -0.1851   0.1433  -1.2920 0.1963 -0.4660  0.0957
# OnlineSecurity_Yes           -0.8111   0.1574  -5.1534 0.0000 -1.1196 -0.5026
# OnlineBackup_No               0.3669   0.0759   4.8373 0.0000  0.2183  0.5156
# TechSupport_No                0.0240   0.1464   0.1637 0.8700 -0.2630  0.3109
# TechSupport_Yes              -0.6106   0.1599  -3.8198 0.0001 -0.9240 -0.2973
# StreamingMovies_Yes           0.3188   0.0895   3.5624 0.0004  0.1434  0.4942
# Contract_Month-to-month       1.3521   0.1639   8.2488 0.0000  1.0308  1.6733
# Contract_One year             0.1669   0.1795   0.9297 0.3525 -0.1849  0.5187
# Contract_Two year            -0.6351   0.2189  -2.9017 0.0037 -1.0641 -0.2061
# PaperlessBilling_No          -0.5648   0.1481  -3.8142 0.0001 -0.8550 -0.2745
# PaperlessBilling_Yes          0.0211   0.1381   0.1528 0.8786 -0.2496  0.2919
# PaymentMethod_Bank transfer  -1.0022   0.0955 -10.4943 0.0000 -1.1894 -0.8150
# PaymentMethod_Credit card    -1.2324   0.1002 -12.3041 0.0000 -1.4287 -1.0361
# PaymentMethod_Mailed check   -0.6330   0.0920  -6.8813 0.0000 -0.8134 -0.4527
# =============================================================================

# %%
cols_remove=["Dependents_No","gender_Male","OnlineSecurity_No","InternetService_No","TechSupport_No","Contract_One year","PaperlessBilling_Yes"]
cols_new =[]
for i in cols:
  if i not in cols_remove:
    cols_new.append(i)

# %%
X=os_data_X[cols_new]
y=os_data_y["Churn"]

logit_model=sm.Logit(y,X)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.445328
#          Iterations 7
#                                Results: Logit
# =============================================================================
# Model:                   Logit                Pseudo R-squared:     0.358
# Dependent Variable:      Churn                AIC:                  6456.9776
# Date:                    2022-04-30 18:07     BIC:                  6560.2384
# No. Observations:        7216                 Log-Likelihood:       -3213.5
# Df Model:                14                   LL-Null:              -5001.8
# Df Residuals:            7201                 LLR p-value:          0.0000
# Converged:               1.0000               Scale:                1.0000
# No. Iterations:          7.0000
# -----------------------------------------------------------------------------
#                               Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------
# tenure                       -0.0146   0.0017  -8.3946 0.0000 -0.0181 -0.0112
# MonthlyCharges                0.2734   0.0775   3.5267 0.0004  0.1214  0.4253
# Dependents_Yes               -0.5657   0.0812  -6.9642 0.0000 -0.7249 -0.4065
# MultipleLines_No             -0.1974   0.0687  -2.8746 0.0040 -0.3321 -0.0628
# InternetService_Fiber optic   0.5985   0.1157   5.1717 0.0000  0.3717  0.8253
# OnlineSecurity_Yes           -0.6384   0.0864  -7.3920 0.0000 -0.8077 -0.4692
# OnlineBackup_No               0.3344   0.0639   5.2357 0.0000  0.2092  0.4595
# TechSupport_Yes              -0.6401   0.0882  -7.2596 0.0000 -0.8129 -0.4673
# StreamingMovies_Yes           0.3223   0.0808   3.9875 0.0001  0.1639  0.4807
# Contract_Month-to-month       1.1835   0.0754  15.6885 0.0000  1.0357  1.3314
# Contract_Two year            -0.7794   0.1583  -4.9247 0.0000 -1.0896 -0.4692
# PaperlessBilling_No          -0.5814   0.0735  -7.9149 0.0000 -0.7254 -0.4374
# PaymentMethod_Bank transfer  -0.9963   0.0947 -10.5225 0.0000 -1.1819 -0.8108
# PaymentMethod_Credit card    -1.2308   0.0996 -12.3610 0.0000 -1.4260 -1.0357
# PaymentMethod_Mailed check   -0.6274   0.0891  -7.0398 0.0000 -0.8020 -0.4527
# =============================================================================

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
xgb_2 = xgb.XGBClassifier(objective="reg:linear", random_state=42)
xgb_2.fit(X_train, y_train)
# Out:
# [18:07:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBClassifier(objective='reg:linear', random_state=42)

# %%
xgb_pred = xgb_2.predict(X_test)
print('\033[1m' + "Model Accuracy" + '\033[0m')
print("Accuracy of the model is:", accuracy_score(y_test, xgb_pred))
print("\n")
print('\033[1m' + "Confusion Matrix" + '\033[0m')
con_mat = pd.DataFrame(confusion_matrix(y_test, xgb_pred), index=['True[0]','True[1]'], 
                       columns=['Predict[0]', 'Predict[1]'])
print(con_mat)
print("\n")
print('\033[1m' + "Classification Report" + '\033[0m')
print(classification_report(y_test, xgb_pred))
# Out:
# Model Accuracy
# Accuracy of the model is: 0.8240184757505774
#
#
# Confusion Matrix
#          Predict[0]  Predict[1]
# True[0]         848         216
# True[1]         165         936
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82      1064
#            1       0.81      0.85      0.83      1101
#
#     accuracy                           0.82      2165
#    macro avg       0.82      0.82      0.82      2165
# weighted avg       0.82      0.82      0.82      2165

# %%
skplt.metrics.plot_roc(y_test, xgb_2.predict_proba(X_test), plot_micro=False)
plt.show()

# %% [markdown]
# **Model developed with Hyperparameter Tuning**

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from scipy.stats import loguniform
from sklearn.model_selection import RandomizedSearchCV

param_grid = {
        'silent': [False],
        'max_depth': [6, 10, 15, 20],
        'learning_rate': [0.001, 0.01, 0.1, 0.2, 0,3],
        'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        'colsample_bytree': [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        'colsample_bylevel': [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        'min_child_weight': [0.5, 1.0, 3.0, 5.0, 7.0, 10.0],
        'gamma': [0, 0.25, 0.5, 1.0],
        'reg_lambda': [0.1, 1.0, 5.0, 10.0, 50.0, 100.0],
        'n_estimators': [100]}

print(param_grid)
# Out:
# {'silent': [False], 'max_depth': [6, 10, 15, 20], 'learning_rate': [0.001, 0.01, 0.1, 0.2, 0, 3], 'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0], 'colsample_bytree': [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0], 'colsample_bylevel': [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0], 'min_child_weight': [0.5, 1.0, 3.0, 5.0, 7.0, 10.0], 'gamma': [0, 0.25, 0.5, 1.0], 'reg_lambda': [0.1, 1.0, 5.0, 10.0, 50.0, 100.0], 'n_estimators': [100]}

# %%
clf_xgb = xgb.XGBClassifier()

cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
rf_RandomGrid = RandomizedSearchCV(estimator = clf_xgb, param_distributions = param_grid, cv = cv, verbose=2, n_jobs = 4)

rf_RandomGrid.fit(X, y)
# Out:
# Fitting 30 folds for each of 10 candidates, totalling 300 fits
# RandomizedSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=1),
#                    estimator=XGBClassifier(), n_jobs=4,
#                    param_distributions={'colsample_bylevel': [0.4, 0.5, 0.6,
#                                                               0.7, 0.8, 0.9,
#                                                               1.0],
#                                         'colsample_bytree': [0.4, 0.5, 0.6, 0.7,
#                                                              0.8, 0.9, 1.0],
#                                         'gamma': [0, 0.25, 0.5, 1.0],
#                                         'learning_rate': [0.001, 0.01, 0.1, 0.2,
#                                                           0, 3],
#                                         'max_depth': [6, 10, 15, 20],
#                                         'min_child_weight': [0.5, 1.0, 3.0, 5.0,
#                                                              7.0, 10.0],
#                                         'n_estimators': [100],
#                                         'reg_lambda': [0.1, 1.0, 5.0, 10.0,
#                                                        50.0, 100.0],
#                                         'silent': [False],
#                                         'subsample': [0.5, 0.6, 0.7, 0.8, 0.9,
#                                                       1.0]},
#                    verbose=2)

# %%
rf_RandomGrid.best_params_
# Out:
# {'colsample_bylevel': 0.7,
#  'colsample_bytree': 1.0,
#  'gamma': 0.25,
#  'learning_rate': 0.1,
#  'max_depth': 10,
#  'min_child_weight': 3.0,
#  'n_estimators': 100,
#  'reg_lambda': 5.0,
#  'silent': False,
#  'subsample': 1.0}

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
xgb_final = xgb.XGBClassifier(colsample_bylevel=0.7, colsample_bytree=0.1, gamma=0.25,
                              learning_rate=0.1, max_depth=10, min_child_weight=3.0,
                              n_estimators=100, reg_lambda=5.0, silent=False, subsample=1.0)
xgb_final.fit(X_train, y_train)
xgb_predictions = xgb_final.predict(X_test)
print('\033[1m' + "Model Accuracy" + '\033[0m')
print("Accuracy of the model is:", (accuracy_score(y_test, xgb_predictions)*100))
print("\n")
print('\033[1m' + "Confusion Matrix" + '\033[0m')
con_mat = pd.DataFrame(confusion_matrix(y_test, xgb_predictions), index=['True[0]','True[1]'], 
                       columns=['Predict[0]', 'Predict[1]'])
print(con_mat)
print("\n")
print('\033[1m' + "Classification Report" + '\033[0m')
print(classification_report(y_test, xgb_predictions))
# Out:
# Model Accuracy
# Accuracy of the model is: 79.67667436489607
#
#
# Confusion Matrix
#          Predict[0]  Predict[1]
# True[0]         811         253
# True[1]         187         914
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.81      0.76      0.79      1064
#            1       0.78      0.83      0.81      1101
#
#     accuracy                           0.80      2165
#    macro avg       0.80      0.80      0.80      2165
# weighted avg       0.80      0.80      0.80      2165

# %%
skplt.metrics.plot_roc(y_test, xgb_final.predict_proba(X_test), plot_micro=False)
plt.show()
